# %% [markdown]
# <a href="https://colab.research.google.com/github/NYahirGranadosVargas/Proyectos-/blob/main/Proyecto_M1_Python_para_Ciencia_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bootcamp Ciencia de Datos e Inteligencia Artificial**
# # **Proyecto Módulo 1. Python para Ciencia de Datos**

# %% [markdown]
# ## Introducción
#
# Has aprendido lo más elemental en tu camino para convertirte en un científico de datos y estás preparado para afrontar una de las actividades más comunes del trabajo cotidiano de un _data scientist_; es decir, revisar y analizar información solicitada por algún cliente.
#
# Este proyecto representa un desafío que tomará algo de tiempo, de manera que necesitarás mucha concentración y persistencia; sin embargo, eres completamente capaz de resolverlo. Así, en cuestión de semanas notarás la facilidad con que realizas este tipo de actividades.

# %% [markdown]
# ## Demo
#
# Este documento te servirá como inspiración para crear el tuyo: https://drive.google.com/file/d/1HH_aauW-84bnoBcooZtT7hRN4bFT5uB8/view?usp=sharing

# %% [markdown]
# ## ¿Qué construirás?
#
# Un documento de Google Colaboratory que funja como introducción a las actividades más comunes de tu labor cotidiana. Considera que este trabajo se convertirá en una guía para los módulos siguientes, dado que practicarás las habilidades básicas necesarias para implementar un modelo.

# %% [markdown]
# ## Objetivos
#
# El participante:
#
# - Se familiarizará con la estructura del lenguaje **Python** enfocada en la ciencia de datos.
# - Comprenderá que cada proyecto solicitado poseerá distintas características (gráficos de un cierto tipo o diseño, algunos datos estadísticos, entre otros).
# - Entenderá que algunos datos se interpretan mejor al utilizar determinadas herramientas, tales como **Pandas**, **Numpy** y **Matplotlib**.
# - Asimilará la manera de estructurar la información que requiera analizar.

# %% [markdown]
# ## Requisitos
#
# - El proyecto se entregará en forma individual.
# - Cada participante deberá completar el archivo de **Google Colab** ubicado en su **Google Drive** personal. Al finalizar, compartirá el enlace en el espacio designado en **Teams**.

# %% [markdown]
# ## Entregables
#
# Cada participante hará una copia del presente documento y la guardará en su **Google Drive** personal.
#
# Leerá cada una de las preguntas y responderá utilizando bloques de código (a excepción de la pregunta 7, que podrá responderse con un bloque de texto).
#
# Los resultados deberán ser inteligibles y se recomienda utilizar funciones como `print` para dar claridad a las respuestas.
#
# Es posible investigar soluciones en otras fuentes o recurrir a clases anteriores; sin embargo, el estudiante debe comprender lo escrito en código.
#
# Algunas respuestas tienen diversas formas de resolverse, no obstante, debe existir precisión en el código escrito y en el propósito que persigue.
#
# ¡Comencemos!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #No quitar

# %% [markdown]
# ### Pregunta 1
# Descarga los siguientes archivos:
# - Este archivo de Excel enlista diferentes celulares y una serie de calificaciones de distintos usuarios: https://drive.google.com/file/d/1atasE-fuDyAt8Z7JGZQroKJwjNkbpyrn/view?usp=sharing
# - Este documento incluye un listado de las marcas de dichos teléfonos celulares: https://drive.google.com/file/d/1ICBvPkSVajVVMHyrMABYiwuwefv_3oPJ/view?usp=sharing
#
# Sube estos archivos en un **Google Drive** y con `pd.read_excel` nómbralos como `df_modelos` y `df_marcas`.
#
# Indica en un solo código el número de filas que tiene el archivo `df_modelos` que creaste.

# %%
#df=pd.read_excel("/content/drive/MyDrive/Ucamp/informacion.xlsx")
#df2=pd.read_csv("/content/drive/MyDrive/Ucamp/df_modelos.csv", encoding='')

df_ma=pd.read_excel("/content/drive/MyDrive/Ucamp/df_marcas.xlsx")
df_mo=pd.read_excel("/content/drive/MyDrive/Ucamp/df_modelos.xlsx")
# Con esto mostramos los primeros 5 elementos 0
#df_ma.head()

# %%
df_ma.head()
# Out:
#    ID Marca Nombre Marca
# 0         1        Apple
# 1         2       I Kall
# 2         3      Infinix
# 3         4         Lava
# 4         5     Motorola

# %%
8#Con esto mostramos los 5 primeros elementos del segundo data
df_mo.head()
# Out:
#    ID Marca                           Modelo  RAM_GB  ROM_GB  Calificaciones  \
# 0        10      Redmi 8 (Onyx Black, 64 GB)       4      64          674638
# 1         9  Realme 5i (Forest Green, 64 GB)       4      64          243106
# 2         9     Realme 5i (Aqua Blue, 64 GB)       4      64          243106
# 3        10   Redmi 8 (Sapphire Blue, 64 GB)       4      32          674638
# 4         8  POCO X2 (Matrix Purple, 128 GB)       6      64          133486
#
#    Rese–as  Estrellas  Precio de lista  Precio de venta
# 0    50064        4.4            10999             9999
# 1    16497        4.5            10999            10999
# 2    16497        4.5            10999            10999
# 3    50064        4.4            10999             9999
# 4    14732        4.5            19999            18499

# %% [markdown]
# *Por lo anterior podemos ver que en los data frames cargados tenemos df_ma dos columnas y df_mo nueve columnas* en las dos hay una columna en comun ID Marca

# %% [markdown]
# ### Pregunta 2
# Haz un `merge` de ambos **data frames**, para generar un nuevo **data frame** que incluya los datos de `df_modelos` y `df_marcas`. Tu nuevo **data frame** recibirá el nombre de `df`.
#
# **Pista**: Ambos archivos tienen una columna que los relaciona, llamada `ID Marca`.

# %%
df=pd.merge(left=df_ma,right=df_mo,on='ID Marca')
df.head(15)
# Out:
#     ID Marca Nombre Marca                                 Modelo  RAM_GB  \
# 0          1        Apple         Apple iPhone XR (Black, 64 GB)       0
# 1          1        Apple         Apple iPhone SE (White, 64 GB)       0
# 2          1        Apple         Apple iPhone SE (Black, 64 GB)       0
# 3          1        Apple  Apple iPhone XR ((PRODUCT)RED, 64 GB)       0
# 4          1        Apple           Apple iPhone SE (Red, 64 GB)       0
# 5          1        Apple        Apple iPhone SE (Black, 128 GB)       0
# 6          1        Apple          Apple iPhone XR (Blue, 64 GB)       0
# 7          1        Apple          Apple iPhone XR (Blue, 64 GB)       0
# 8          1        Apple     Apple iPhone 7 Plus (Black, 32 GB)       0
# 9          1        Apple        Apple iPhone XR (White, 128 GB)       0
# 10         1        Apple         Apple iPhone XR (White, 64 GB)       0
# 11         2       I Kall                 I Kall K6 (Red, 32 GB)       4
# 12         2       I Kall             I Kall K1000 (Blue, 64 GB)       4
# 13         2       I Kall              I Kall K220 (Blue, 16 GB)       2
# 14         2       I Kall              I Kall K400 (Blue, 64 GB)       4
#
#     ROM_GB  Calificaciones  Rese–as  Estrellas  Precio de lista  \
# 0       32           11572      975        4.6            52500
# 1       64           12954     1298        4.5            42500
# 2       32           12954     1298        4.5            42500
# 3       64           11572      975        4.6            52500
# 4      128           12954     1298        4.5            42500
# 5       64           12954     1298        4.5            47800
# 6      128           11572      975        4.6            52500
# 7       64           11572      975        4.6            52500
# 8       64           27442     2853        4.5            37900
# 9       64           11572      975        4.6            57800
# 10      64           11572      975        4.6            52500
# 11      64             615       57        3.0             7299
# 12      32             840      111        2.9             7699
# 13      64              58        3        3.1             5699
# 14      16             512       47        2.8             7299
#
#     Precio de venta
# 0             46999
# 1             40999
# 2             40999
# 3             46999
# 4             40999
# 5             45999
# 6             46999
# 7             46999
# 8             34999
# 9             52999
# 10            46999
# 11             6699
# 12             7699
# 13             5499
# 14             7299

# %% [markdown]
# Como se puede ver la columna en comun va al principio y se acomoda como lo dice el merge.

# %% [markdown]
# ### Pregunta 3
# Muestra las primeras cinco filas, las últimas cinco y el nombre de todas las columnas.

# %%
#df.head(-5)
df.tail()
# Out:
#      ID Marca Nombre Marca                              Modelo  RAM_GB  \
# 115        12         Vivo     Vivo Y91i (Fusion Black, 32 GB)       2
# 116        12         Vivo       Vivo Y91i (Ocean Blue, 32 GB)       2
# 117        12         Vivo  Vivo S1 Pro (Mystic Black, 128 GB)       8
# 118        12         Vivo    Vivo Y30 (Emerald Black, 128 GB)       4
# 119        12         Vivo      Vivo Y30 (Dazzle Blue, 128 GB)       4
#
#      ROM_GB  Calificaciones  Rese–as  Estrellas  Precio de lista  \
# 115     128           21196     1445        4.3             9990
# 116     128           21196     1445        4.3             9990
# 117     128           11571      891        4.4            20990
# 118      32             604       44        4.3            18990
# 119     128             604       44        4.3            18990
#
#      Precio de venta
# 115             7990
# 116             7990
# 117            19990
# 118            14990
# 119            14990

# %%
df.columns
# Out:
# Index(['ID Marca', 'Nombre Marca', 'Modelo', 'RAM_GB', 'ROM_GB',
#        'Calificaciones', 'Rese–as', 'Estrellas', 'Precio de lista',
#        'Precio de venta'],
#       dtype='object')

# %% [markdown]
# ### Pregunta 4
# Utiliza los filtros para mostrar todos los teléfonos con 64GB en la columna `ROM_GB` e indica cuántos del listado poseen esta característica.

# %%
df[df['ROM_GB']==64]
# Out:
#      ID Marca Nombre Marca                                 Modelo  RAM_GB  \
# 1           1        Apple         Apple iPhone SE (White, 64 GB)       0
# 3           1        Apple  Apple iPhone XR ((PRODUCT)RED, 64 GB)       0
# 5           1        Apple        Apple iPhone SE (Black, 128 GB)       0
# 7           1        Apple          Apple iPhone XR (Blue, 64 GB)       0
# 8           1        Apple     Apple iPhone 7 Plus (Black, 32 GB)       0
# ..        ...          ...                                    ...     ...
# 104        12         Vivo         Vivo Y15 (Burgundy Red, 64 GB)       4
# 105        12         Vivo            Vivo Y15 (Aqua Blue, 64 GB)       4
# 106        12         Vivo            Vivo Y12 (Aqua Blue, 64 GB)       3
# 108        12         Vivo            Vivo Y11 (Agate Red, 32 GB)       3
# 111        12         Vivo        Vivo U10 (Thunder Black, 32 GB)       3
#
#      ROM_GB  Calificaciones  Rese–as  Estrellas  Precio de lista  \
# 1        64           12954     1298        4.5            42500
# 3        64           11572      975        4.6            52500
# 5        64           12954     1298        4.5            47800
# 7        64           11572      975        4.6            52500
# 8        64           27442     2853        4.5            37900
# ..      ...             ...      ...        ...              ...
# 104      64           20969     1505        4.4            15990
# 105      64           20969     1505        4.4            15990
# 106      64           13266      981        4.4            13990
# 108      64            4744      268        4.4             9990
# 111      64           34333     2395        4.4            10990
#
#      Precio de venta
# 1              40999
# 3              46999
# 5              45999
# 7              46999
# 8              34999
# ..               ...
# 104            12990
# 105            12990
# 106            10990
# 108             9990
# 111            10990
#
# [62 rows x 10 columns]

# %% [markdown]
# ### Pregunta 5
# Haz un histograma (`hist`) de la columna `ROM_GB` del **data frame** `df`.
#
# El gráfico debe incluir un título y las columnas tener un color personalizado.

# %%
plt.hist(df['ROM_GB'],20,color='blue')
# Out:
# (array([ 1.,  5.,  0.,  0., 30.,  0.,  0.,  0.,  0., 62.,  0.,  0.,  0.,
#          0.,  0.,  0.,  0.,  0.,  0., 22.]),
#  array([  4. ,  10.2,  16.4,  22.6,  28.8,  35. ,  41.2,  47.4,  53.6,
#          59.8,  66. ,  72.2,  78.4,  84.6,  90.8,  97. , 103.2, 109.4,
#         115.6, 121.8, 128. ]),
#  <BarContainer object of 20 artists>)

# %%
fig , ax=plt.subplots(figsize=(15,5))
x=df['ROM_GB']
ax.hist(x,color='green',bins=15,edgecolor='black')

ax.set_title('Resultado del histograma')
ax.set_xlabel('Cantidad de memoria ROM')
ax.set_ylabel('Cantidad de celulares')
plt.show()

# %% [markdown]
# ### Pregunta 6
# Haz un diagrama de dispersión (`scatter`) con las siguientes características: el eje X deberá indicar el contenido de la columna `Precio de lista`, mientras que el eje Y expresará el contenido de la columna `Precio de venta`.
#
# El diagrama debe incluir un título y los puntos tener un color personalizado.

# %%
fig,bx=plt.subplots(figsize=(15,10))
x1=df['Precio de lista']
y1=df['Precio de venta']
bx.scatter(x1,y1,color='black',lw=1.5)
bx.set_title('Relacion entre precio de lista y percio de venta')
bx.set_xlabel('Precio de lista')
bx.set_ylabel('Precio de venta')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Pregunta 7
#
# Con base en el diagrama de la **pregunta 6**, responde la siguiente pregunta: ¿A qué conclusión podrías llegar si observas únicamente la gráfica?

# %% [markdown]
# El precio de lista y el de venta coiciden en un margen de 8000 a 23000

# %% [markdown]
# ### Pregunta 8
# Utiliza el código para obtener la siguiente información (ubicada en `df`).
#
# - Promedio de los precios de venta de los modelos marca **Realme**
# - Máximo de estrellas de los modelos marca **Redmi**
# - Mínimo de Estrellas de los modelos marca **Redmi**

# %%
df[df['Nombre Marca']=='Realme'].mean() # Saca el promedio de todas la columnas que tiene el DF
# Out:
# <ipython-input-20-e3f40bbb7fc4>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df['Nombre Marca']=='Realme'].mean() # Saca el promedio de todas la columnas que tiene el DF
# ID Marca                9.000000
# RAM_GB                  4.303030
# ROM_GB                 66.424242
# Calificaciones     111534.454545
# Rese–as              8935.212121
# Estrellas               4.475758
# Precio de lista     13089.909091
# Precio de venta     12423.242424
# dtype: float64

# %%
df.groupby(by='Nombre Marca')['Precio de venta'].mean()
# Out:
# Nombre Marca
# Apple       44726.272727
# I Kall       6322.846154
# Infinix      9936.500000
# Lava         1699.000000
# Motorola     9499.000000
# Nokia        1299.000000
# Oppo        12990.000000
# Poco        18699.000000
# Realme      12423.242424
# Redmi       12410.300000
# Tecno       10999.000000
# Vivo        13052.500000
# Name: Precio de venta, dtype: float64

# %%
aux=df[df['Nombre Marca']=='Realme']
aux.head()
aux.groupby(by='Nombre Marca')['Precio de venta'].mean()
# Out:
# Nombre Marca
# Realme    12423.242424
# Name: Precio de venta, dtype: float64

# %%
aux1=df[df['Nombre Marca']=='Redmi']
aux1.head()
# Out:
#     ID Marca Nombre Marca                                    Modelo  RAM_GB  \
# 91        10        Redmi               Redmi 8 (Onyx Black, 64 GB)       4
# 92        10        Redmi            Redmi 8 (Sapphire Blue, 64 GB)       4
# 93        10        Redmi  Redmi Note 8 Pro (Electric Blue, 128 GB)       6
# 94        10        Redmi           Redmi 8A Dual (Sea Blue, 64 GB)       3
# 95        10        Redmi           Redmi 8A Dual (Sea Blue, 32 GB)       2
#
#     ROM_GB  Calificaciones  Rese–as  Estrellas  Precio de lista  \
# 91      64          674638    50064        4.4            10999
# 92      32          674638    50064        4.4            10999
# 93      64           55815     4614        4.4            17999
# 94      64             974       71        4.3             9750
# 95      64            1246       81        4.2             8320
#
#     Precio de venta
# 91             9999
# 92             9999
# 93            16999
# 94             9750
# 95             8320

# %%
aux1['Estrellas'].max()
# Out:
# 4.4

# %%
aux1['Estrellas'].min()
# Out:
# 4.2

# %%
np.sort(aux1['Estrellas'])
# Out:
# array([4.2, 4.2, 4.3, 4.3, 4.4, 4.4, 4.4, 4.4, 4.4, 4.4])

# %% [markdown]
# ### Pregunta 9
# Utiliza un **Groupby** para mostrar la cantidad de estrellas promedio que cada marca tiene en `df`.

# %%
df_ma.head(12)
# Out:
#     ID Marca Nombre Marca
# 0          1        Apple
# 1          2       I Kall
# 2          3      Infinix
# 3          4         Lava
# 4          5     Motorola
# 5          6        Nokia
# 6          7         Oppo
# 7          8         Poco
# 8          9       Realme
# 9         10        Redmi
# 10        11        Tecno
# 11        12         Vivo

# %%
aux_MP1=df[df['Nombre Marca']=='Apple']
aux_MP2=df[df['Nombre Marca']=='I Kall']
aux_MP3=df[df['Nombre Marca']=='Infinix']
aux_MP4=df[df['Nombre Marca']=='Lava']
aux_MP5=df[df['Nombre Marca']=='Motorola']
aux_MP6=df[df['Nombre Marca']=='Nokia']
aux_MP7=df[df['Nombre Marca']=='Oppo']
aux_MP8=df[df['Nombre Marca']=='Poco']
aux_MP9=df[df['Nombre Marca']=='Realme']
aux_MP10=df[df['Nombre Marca']=='Redmi']
aux_MP11=df[df['Nombre Marca']=='Tecno']
aux_MP12=df[df['Nombre Marca']=='Vivo']

# %%
aux_MP1['Estrellas'].mean()
# Out:
# 4.554545454545455

# %%
df_Marcas=df.groupby(by='Nombre Marca')['Nombre Marca','Estrellas'].mean()
df_Marcas.head(12)

#['Apple','I Kall','Infinix','Lava','Motorola','Nokia','Oppo','Poco','Realme','Redmi','Tecno','Vivo']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#               Estrellas
# Nombre Marca
# Apple          4.554545
# I Kall         2.984615
# Infinix        4.387500
# Lava           4.100000
# Motorola       4.400000
# Nokia          4.300000
# Oppo           4.325000
# Poco           4.500000
# Realme         4.475758
# Redmi          4.340000
# Tecno          4.266667
# Vivo           4.375000

# %% [markdown]
# ### Pregunta 10
# ¿Qué otro dato puedes obtener de `df` y cómo lo extraerías?

# %%
df_Marcas1=df.groupby(by='ID Marca')['Nombre Marca','RAM_GB','Precio de venta']
df_Marcas1.head(12)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#     Nombre Marca  RAM_GB  Precio de venta
# 0          Apple       0            46999
# 1          Apple       0            40999
# 2          Apple       0            40999
# 3          Apple       0            46999
# 4          Apple       0            40999
# ..           ...     ...              ...
# 111         Vivo       3            10990
# 112         Vivo       6            16990
# 113         Vivo       6            16990
# 114         Vivo       8            18990
# 115         Vivo       2             7990
#
# [90 rows x 3 columns]
